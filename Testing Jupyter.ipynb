# %% [markdown]
# # Headline 1
#
# *Note: italicized text*
#
# ## Headline 2
#
# Normal text.
#
# Basic formatting *italic* and **bold**
#
# ### Headline 3
#
# 1. item 1
# 2. item 2
# 3. item 4

# %%
# %lsmagic

# %% [markdown]
# A simple illustration of the trapezoid rule for definite integration:
#
# $$
# \int_{a}^{b} f(x)\, dx \approx \frac{1}{2} \sum_{k=1}^{N} \left( x_{k} - x_{k-1} \right) \left( f(x_{k}) + f(x_{k-1}) \right).
# $$
# <br>
# First, we define a simple function and sample it between 0 and 10 at 200 points

# %%
"""
Simple demo of a scatter plot 
"""
# interactive plots
#%matplotlib notebook
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2

plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/v7qYdYzvhs4" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/v7qYdYzvhs4" frameborder="0" allowfullscreen></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('v7qYdYzvhs4')

# %%
# %%timeit
square_events = [n*n for n in range(1000)]
# Out:
# 48.6 µs ± 680 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,5))
df
# Out:
#           0         1         2         3         4
# 0 -0.378279  0.766469  1.509927 -0.219931 -0.481895
# 1  0.295701 -0.792743  0.256010  0.798898  0.180574
# 2  0.244738 -0.839104 -1.010810 -0.224374  1.360823
# 3 -0.532228  0.453948 -0.501178 -1.399238 -2.636982
# 4 -1.671621  1.132740 -0.087214 -0.600176  1.397296
# 5 -0.222833 -0.366531 -1.221589 -0.827258  1.288630
# 6  0.858251 -1.342100  1.168809 -0.544569 -0.452091
# 7  0.051450  1.636338 -0.453560 -0.564882 -0.707303
# 8  0.785586 -0.404763  0.717957 -1.386799 -2.054096
# 9 -0.795067 -0.863130 -0.705174  0.956612 -1.173918

# %%
from IPython.display import Audio
import numpy as np
import matplotlib.pyplot as plt

max_time = 3
f1 = 220
f2 = 224
rate = 8000
L = 3
times = np.linspace(0,L,rate*L)
signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)

plt.plot(signal)
Audio(data=signal, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%HTML
# <iframe width="800" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="https://www.openstreetmap.org/export/embed.html?bbox=8.73958969168598%2C50.20130307118419%2C8.749631882237736%2C50.20587657014726&amp;layer=mapnik" style="border: 1px solid black"></iframe><br/><small><a href="https://www.openstreetmap.org/#map=17/50.20359/8.74461">View Larger Map</a></small>
# Out:
# <iframe width="800" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="https://www.openstreetmap.org/export/embed.html?bbox=8.73958969168598%2C50.20130307118419%2C8.749631882237736%2C50.20587657014726&amp;layer=mapnik" style="border: 1px solid black"></iframe><br/><small><a href="https://www.openstreetmap.org/#map=17/50.20359/8.74461">View Larger Map</a></small>
